# %% [markdown]
# # Tests on Pos train set data

# %%
import pandas as pd

df = pd.read_csv("data/pos_train_set.csv")

# %%
df.head()
# Out:
#    Date                                            Fallacy              Label  \
# 0  2004  In fact, it's starting to fall apart not becau...         FalseCause
# 1  1976  We've got an extraordinarily high unemployment...    AppealtoEmotion
# 2  2008  Admiral Mullen suggests that Senator Obama's p...  AppealtoAuthority
# 3  2016         I don't believe she does have the stamina.          AdHominem
# 4  2004                        the most significant effort    AppealtoEmotion
#
#         Subcategory arg_comp  arg_rel  \
# 0       False cause  Premise   Attack
# 1    Appeal to pity  Premise  Support
# 2  Without Evidence    Claim      NaN
# 3        Ad hominem    Claim  Support
# 4   Loaded Language    Claim      NaN
#
#                                              Context  \
# 0  And there is no system. In fact, it's starting...
# 1  The last point is that the major - uh thrust h...
# 2  And right now, the commanders in Afghanistan, ...
# 3  I said she doesn't have the stamina. And I don...
# 4  I've tried to find the common ground, because ...
#
#                                             bio_tags  \
# 0  ['O', 'O', 'O', 'O', 'O', 'B-FalseCause', 'I-F...
# 1  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 2  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Ad...
# 4  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
#
#                                             pos_tags
# 0  CCONJ,PRON,VERB,DET,NOUN,PUNCT,ADP,NOUN,PUNCT,...
# 1  DET,ADJ,NOUN,AUX,SCONJ,DET,ADJ,PUNCT,INTJ,NOUN...
# 2  CCONJ,ADV,ADV,PUNCT,DET,NOUN,ADP,PROPN,PUNCT,A...
# 3  PRON,VERB,PRON,AUX,PART,VERB,DET,NOUN,PUNCT,CC...
# 4  PRON,AUX,VERB,PART,VERB,DET,ADJ,NOUN,PUNCT,SCO...

# %%
from ollama import chat

model = "deepseek-r1:8b"

df["result"] = ""
for i in range (len(df)):
    text = df["Fallacy"][i]
    display(text)
    formated_promt = promt.format(text=text)
    messages = [
            {
                "role": "user",
                "content": formated_promt
            }
        ]

    response = chat(model, messages = messages)['message']['content']
    display(response)
    df["result"][i] = response
# Out:
# Jupyter cannot be started. Error attempting to locate Jupyter: 'Kernelspec' module not installed in the selected interpreter (/home/david/ownCloud/Personal/Structures/Democracy_Slaps/tweede-kamer/.venv/bin/python).
#
#  Please re-install or update 'jupyter'.
#
# Run the following command to install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.
